# %% [markdown]
# # Question 8
# -Use nps_chat and wordlist corpus.
# -If you find a word in nps_chat but not in wordlist, it is considered an unusual word. (e.g. Heyyyy, gr8, 4ever can be considered unusual words for this analysis)
# -Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# -Bonus: What if I want to  count : ) , : ( all these emoticons in. (optional)

# %%
import nltk
from nltk.corpus import nps_chat

# %%
def unusual_words(x):
    word_in_chat = set(a.lower() for a in x if a.isalpha())
    word_list = set(a.lower() for a in nltk.corpus.words.words())
    unusualWord = word_in_chat - word_list
    return set(sorted(unusualWord))

unusual_words(nltk.corpus.nps_chat.words())
# Out:
# {'tounge',
#  'lmaooooo',
#  'ahah',
#  'flames',
#  'dreams',
#  'grrrrrring',
#  'pleaseeeee',
#  'numbers',
#  'jacking',
#  'flippin',
#  'polllution',
#  'seconds',
#  'asked',
#  'fuked',
#  'ahhhhhhhhhhhhhh',
#  'boning',
#  'enuff',
#  'wussups',
#  'humple',
#  'google',
#  'jujubees',
#  'heyyyyyyyyy',
#  'neysa',
#  'uses',
#  'gays',
#  'meds',
#  'moved',
#  'nods',
#  'johny',
#  'affari',
#  'bishes',
#  'fingers',
#  'sores',
#  'fl',
#  'roadrunner',
#  'fits',
#  'knuckles',
#  'grea',
#  'yikes',
#  'leakin',
#  'sounds',
#  'wahoooooooski',
#  'jeter',
#  'remembah',
#  'outs',
#  'nz',
#  'banjoes',
#  'themself',
#  'divorced',
#  'pms',
#  'bitches',
#  'dood',
#  'jammed',
#  'alohaaa',
#  'massaged',
#  'lives',
#  'passed',
#  'whooo',
#  'children',
#  'moths',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'shoppin',
#  'sorta',
#  'pweeze',
#  'withdrawl',
#  'nicname',
#  'poeple',
#  'knockin',
#  'facilitated',
#  'oooooooooooo',
#  'vbox',
#  'trolls',
#  'convo',
#  'puts',
#  'yerself',
#  'adds',
#  'gotta',
#  'hmm',
#  'baaaaalllllllliiiiiiinnnnnnnnnnn',
#  'garciae',
#  'loc',
#  'congrat',
#  'wothough',
#  'macho',
#  'johnson',
#  'url',
#  'lmaooo',
#  'popped',
#  'watchin',
#  'dropped',
#  'tigers',
#  'goooooo',
#  'prisoners',
#  'joined',
#  'rotflmao',
#  'hands',
#  'tooo',
#  'youre',
#  'shaneeeeeeeee',
#  'cardnials',
#  'bbiam',
#  'loved',
#  'wantin',
#  'scrolls',
#  'awwwwwwwwww',
#  'whered',
#  'ssid',
#  'niceeeee',
#  'hmmmm',
#  'noooooooooooooo',
#  'hugsssssssss',
#  'cams',
#  'rumour',
#  'towels',
#  'hafta',
#  'plows',
#  'heeeey',
#  'helloooo',
#  'baord',
#  'huskers',
#  'actualy',
#  'sweeeeeeeeet',
#  'tlak',
#  'haters',
#  'mopeds',
#  'problems',
#  'nada',
#  'moped',
#  'plssss',
#  'prays',
#  'hawaii',
#  'whos',
#  'receprion',
#  'gurrrrl',
#  'serties',
#  'brwn',
#  'nooo',
#  'ty',
#  'pffft',
#  'london',
#  'anygirl',
#  'wheels',
#  'messages',
#  'impared',
#  'wishes',
#  'kellogs',
#  'hallo',
#  'jackie',
#  'headach',
#  'tennessee',
#  'bbs',
#  'awwww',
#  'waaa',
#  'donuts',
#  'callifornia',
#  'girlfriend',
#  'heard',
#  'starts',
#  'hubbys',
#  'rapest',
#  'oo',
#  'buses',
#  'descriminate',
#  'powter',
#  'ghet',
#  'stories',
#  'mikeeeeeeeeeeeeeeeeeeeeeeeeee',
#  'soakin',
#  'beleive',
#  'nothin',
#  'liked',
#  'laters',
#  'yikesssss',
#  'whistles',
#  'wins',
#  'sexs',
#  'umm',
#  'chatt',
#  'mwahs',
#  'handheld',
#  'killeded',
#  'mising',
#  'hiyas',
#  'canehda',
#  'eyes',
#  'playstation',
#  'balad',
#  'blazed',
#  'sneezed',
#  'pullin',
#  'gurlie',
#  'cookies',
#  'loveliest',
#  'depeche',
#  'kawing',
#  'diggin',
#  'named',
#  'files',
#  'marlaya',
#  'magine',
#  'gguyyyzzzz',
#  'tips',
#  'grilfriend',
#  'kold',
#  'weeeeeeeeeeeeeeeeeeeeeeeeed',
#  'woooooooooaaaahhhhhhhhhhhh',
#  'gurls',
#  'awsome',
#  'whaaaaats',
#  'questioned',
#  'ringtones',
#  'sighs',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee',
#  'profilrs',
#  'fella',
#  'biyatch',
#  'backfrontsidewaysandallaroundtheworld',
#  'moms',
#  'headlights',
#  'controllers',
#  'fails',
#  'removes',
#  'sumfin',
#  'dahlin',
#  'pushed',
#  'repeats',
#  'innit',
#  'alwys',
#  'whjat',
#  'myspace',
#  'dunno',
#  'gaspppp',
#  'ohhhhhhhhhhhhhhhh',
#  'sesky',
#  'worl',
#  'cheking',
#  'farms',
#  'nakie',
#  'checkin',
#  'typed',
#  'definately',
#  'chatroom',
#  'ct',
#  'dr',
#  'fishercat',
#  'sux',
#  'thanksss',
#  'ciara',
#  'yoder',
#  'escaped',
#  'ewwwwww',
#  'xbox',
#  'pmsl',
#  'declaw',
#  'neone',
#  'ummm',
#  'buh',
#  'chineese',
#  'tv',
#  'immersed',
#  'hel',
#  'ignored',
#  'ahhhhhh',
#  'mittens',
#  'sweats',
#  'fellows',
#  'lolololll',
#  'geeks',
#  'gezzz',
#  'lacking',
#  'lovin',
#  'mothas',
#  'iamahotnipwithpics',
#  'answering',
#  'nashville',
#  'skateboard',
#  'soo',
#  'photshopped',
#  'means',
#  'assholes',
#  'este',
#  'nite',
#  'salut',
#  'women',
#  'whoopz',
#  'barbie',
#  'shhhh',
#  'dated',
#  'ft',
#  'impressed',
#  'cmon',
#  'dem',
#  'redneck',
#  'warnings',
#  'ohwa',
#  'rutger',
#  'coupons',
#  'kookies',
#  'temptations',
#  'splains',
#  'coughed',
#  'ques',
#  'guns',
#  'mmmmmmmmmm',
#  'hyy',
#  'covers',
#  'looks',
#  'snores',
#  'mainland',
#  'byes',
#  'excuuuuuuse',
#  'howz',
#  'schlep',
#  'sites',
#  'soybeans',
#  'permenant',
#  'hellos',
#  'fulfilling',
#  'waht',
#  'wb',
#  'takers',
#  'chattin',
#  'died',
#  'goodnite',
#  'homeade',
#  'nebraska',
#  'huuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuugz',
#  'naples',
#  'flattered',
#  'hugsssss',
#  'lbs',
#  'brothers',
#  'licks',
#  'biiiiiitch',
#  'tks',
#  'burns',
#  'prittier',
#  'sullivan',
#  'wowsa',
#  'heyyyyyyyyyy',
#  'fiddles',
#  'fucks',
#  'doupt',
#  'fallout',
#  'porn',
#  'happened',
#  'specalily',
#  'lets',
#  'alotta',
#  'placce',
#  'bothering',
#  'pisses',
#  'smewchies',
#  'paitently',
#  'lookin',
#  'ebay',
#  'hix',
#  'nce',
#  'mmmkay',
#  'psh',
#  'munches',
#  'couldnt',
#  'nickleback',
#  'weapons',
#  'niters',
#  'ooopppps',
#  'adjusts',
#  'hiom',
#  'ewwwwwww',
#  'willis',
#  'awrighty',
#  'tc',
#  'trippin',
#  'allo',
#  'splelnig',
#  'eay',
#  'irc',
#  'sexist',
#  'fart',
#  'suprised',
#  'chococake',
#  'priorities',
#  'cardinals',
#  'lpn',
#  'lawl',
#  'worries',
#  'surfing',
#  'brings',
#  'tickets',
#  'kev',
#  'warts',
#  'welll',
#  'opps',
#  'youuuu',
#  'kts',
#  'moonie',
#  'observed',
#  'hooo',
#  'il',
#  'involves',
#  'lb',
#  'missin',
#  'wonders',
#  'woooohoooo',
#  'll',
#  'coudl',
#  'fuckin',
#  'goin',
#  'females',
#  'suggestions',
#  'awesomee',
#  'birdgang',
#  'messaging',
#  'daveeee',
#  'nawp',
#  'oy',
#  'ladz',
#  'chica',
#  'indiantown',
#  'cereals',
#  'hahaaa',
#  'sry',
#  'shades',
#  'wazz',
#  'poorrr',
#  'asses',
#  'barbieee',
#  'goneee',
#  'hmph',
#  'downloading',
#  'issues',
#  'gags',
#  'makes',
#  'quizes',
#  'gees',
#  'mahn',
#  'sheesin',
#  'hahahahahahahahahahahahahahahaha',
#  'jammers',
#  'syck',
#  'hunters',
#  'kewl',
#  'robbie',
#  'denzel',
#  'dirrrrty',
#  'chanowner',
#  'alternatives',
#  'sayn',
#  'wc',
#  'clinicals',
#  'played',
#  'freeezinggggg',
#  'nbc',
#  'manson',
#  'mmmm',
#  'words',
#  'boobs',
#  'everytime',
#  'limits',
#  'que',
#  'watches',
#  'hearin',
#  'defrags',
#  'impaired',
#  'categories',
#  'neked',
#  'okies',
#  'xxxxxxxxxx',
#  'gained',
#  'hes',
#  'fawker',
#  'usa',
#  'ssri',
#  'cooooooooookiiiiiiiiiiiieeeeeeeeeeee',
#  'heyyyy',
#  'typin',
#  'miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'cookie',
#  'mmmmk',
#  'keys',
#  'muahhh',
#  'tx',
#  'nauty',
#  'grrrrrrrrrrrrrrrrr',
#  'doody',
#  'thnx',
#  'cuddlicious',
#  'foxes',
#  'wz',
#  'blowjob',
#  'fck',
#  'spose',
#  'tryina',
#  'sips',
#  'noth',
#  'drags',
#  'strangers',
#  'jerketts',
#  'rules',
#  'dratts',
#  'italy',
#  'opr',
#  'drivers',
#  'anithing',
#  'chickens',
#  'qwertyuiop',
#  'footprints',
#  'othah',
#  'yw',
#  'walderslade',
#  'lool',
#  'paradis',
#  'chathide',
#  'adduser',
#  'cali',
#  'aussies',
#  'ones',
#  'scrambled',
#  'dman',
#  'called',
#  'dat',
#  'aime',
#  'happend',
#  'tere',
#  'slaps',
#  'jr',
#  'sexcite',
#  'walked',
#  'wyte',
#  'costumes',
#  'alterz',
#  'deaths',
#  'kansas',
#  'sleepover',
#  'checks',
#  'flatts',
#  'scares',
#  'ifr',
#  'ltr',
#  'teachers',
#  'yepper',
#  'youuu',
#  'aiiiiiiiiiiiiiiiiiiiiiiii',
#  'unisom',
#  'hahhaa',
#  'wimmins',
#  'months',
#  'chuckles',
#  'humm',
#  'ads',
#  'du',
#  'wats',
#  'gng',
#  'oates',
#  'fishin',
#  'atl',
#  'flavors',
#  'gayoholic',
#  'hfglhs',
#  'perth',
#  'hitting',
#  'bf',
#  'names',
#  'euphamisms',
#  'compliments',
#  'kissed',
#  'cakes',
#  'wonderin',
#  'oopps',
#  'peolpe',
#  'dawnstar',
#  'email',
#  'lolol',
#  'bwahahahahahahahahahaha',
#  'laughed',
#  'roomate',
#  'yards',
#  'hiding',
#  'anythin',
#  'thugs',
#  'thang',
#  'alzheimers',
#  'freaks',
#  'sucka',
#  'hours',
#  'ears',
#  'kidding',
#  'llloooozzzzeeerrrrzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'cleared',
#  'says',
#  'grrl',
#  'drivin',
#  'tackles',
#  'backatchya',
#  'images',
#  'subscriptions',
#  'nails',
#  'hb',
#  'hiy',
#  'apoligize',
#  'ewwwww',
#  'allergies',
#  'nekkies',
#  'hehehe',
#  'oooooo',
#  'mama',
#  'catterick',
#  'sowwy',
#  'nooooo',
#  'salisbury',
#  'lucifuge',
#  'ogan',
#  'beatles',
#  'perved',
#  'hangs',
#  'va',
#  'abortions',
#  'dreammm',
#  'bied',
#  'tisk',
#  'gottsa',
#  'wings',
#  'imma',
#  'hugggs',
#  'wellbutrin',
#  'newp',
#  'hmmmmm',
#  'others',
#  'ovr',
#  'jk',
#  'doin',
#  'moanz',
#  'chatr',
#  'lovers',
#  'perked',
#  'gotaa',
#  'weeeeeeeeeeeeeeee',
#  'wel',
#  'changing',
#  'stairs',
#  'dokey',
#  'whuuped',
#  'perv',
#  'trippy',
#  'chik',
#  'hrs',
#  'cusion',
#  'raining',
#  'yoooou',
#  'tdr',
#  'darlings',
#  'exchanged',
#  'msutah',
#  'jonesboro',
#  'sets',
#  'latina',
#  'guys',
#  'teenagers',
#  'ontrobution',
#  'typing',
#  'moans',
#  'chews',
#  'casts',
#  'ribs',
#  'freaking',
#  'kool',
#  'chokes',
#  'outa',
#  'mspace',
#  'fractured',
#  'biatch',
#  'attracted',
#  'invisiable',
#  'pigs',
#  'huggss',
#  'cus',
#  'sposs',
#  'erics',
#  'awwwwwww',
#  'hheeyyy',
#  'cuz',
#  'elbows',
#  'topics',
#  'welcomes',
#  'teh',
#  'appologise',
#  'affairs',
#  'reads',
#  'tennesee',
#  'clubs',
#  'enjoys',
#  'whys',
#  'yeh',
#  'movin',
#  'kid',
#  'glitches',
#  'duh',
#  'woods',
#  'flops',
#  'vvil',
#  'beans',
#  'perving',
#  'itches',
#  'okikes',
#  'donno',
#  'dawg',
#  'losted',
#  'phylosipher',
#  'contemplating',
#  'homies',
#  'gorda',
#  'clooney',
#  'england',
#  'onuimso',
#  'eng',
#  'entitled',
#  'ahhahahaha',
#  'whitesnake',
#  'benz',
#  'eticket',
#  'beeeeehave',
#  'nickelback',
#  'hmmmmmmmm',
#  'oi',
#  'homes',
#  'intersting',
#  'haaa',
#  'sisters',
#  'sp',
#  'pc',
#  'fragged',
#  'lmfao',
#  'gs',
#  'gettign',
#  'remembers',
#  'blondes',
#  'loves',
#  'uhhh',
#  'gentlemen',
#  'gaaaaaaay',
#  'pissed',
#  'oatmel',
#  'pulling',
#  'enters',
#  'cheers',
#  'pounces',
#  'farting',
#  'ooperative',
#  'currious',
#  'sales',
#  'ages',
#  'bacl',
#  'eeewwwwww',
#  'laffs',
#  'singleeeeeeee',
#  'boys',
#  'dontcha',
#  'sleeps',
#  'puzzles',
#  'asshole',
#  'shocked',
#  'hpa',
#  'sleepin',
#  'bro',
#  'gtg',
#  'chocha',
#  'ahahh',
#  'ahahah',
#  'leaders',
#  'mauh',
#  'caps',
#  'ships',
#  'asl',
#  'seems',
#  'tits',
#  'heads',
#  'wooooooooooooohoooooooooooooooo',
#  'dreaded',
#  'dryer',
#  'lyin',
#  'grins',
#  'hugs',
#  'reminded',
#  'bloe',
#  'aynawy',
#  'ive',
#  'ntmn',
#  'akdt',
#  'seee',
#  'comments',
#  'gives',
#  'hehehee',
#  'lmao',
#  'yu',
#  'lil',
#  'cramps',
#  'firs',
#  'listenin',
#  'ms',
#  'thanx',
#  'acros',
#  'uk',
#  'sw',
#  'louisianna',
#  'counts',
#  'eggs',
#  'weeeeeeeeeeeeeeeeee',
#  'otay',
#  'coolcat',
#  'smells',
#  'wanted',
#  'ico',
#  'concernin',
#  'laptop',
#  'raed',
#  'closes',
#  'dances',
#  'shorty',
#  'hogs',
#  'pp',
#  'extensions',
#  'fillin',
#  'thows',
#  'mmhmm',
#  'wears',
#  'metallica',
#  'paints',
#  'ciao',
#  'depends',
#  'urls',
#  'hahaaaa',
#  'evah',
#  'nm',
#  'wuuppin',
#  'hom',
#  'boght',
#  'snuggles',
#  'outta',
#  'wubs',
#  'appearently',
#  'guyzz',
#  'cleveland',
#  'ahhah',
#  'forwads',
#  'hmmmmmmm',
#  'luvs',
#  'cards',
#  'shoots',
#  'harley',
#  'hhehe',
#  'balls',
#  'jumpin',
#  'wisconsin',
#  'sf',
#  'chics',
#  'silverstein',
#  'minutes',
#  'games',
#  'hgfhgfjgf',
#  'bares',
#  'wearin',
#  'oooooooooooglyyyyyyyy',
#  'aaaaaaaaaaaaaaaaa',
#  'boi',
#  'downnnnnn',
#  'arrested',
#  'babblein',
#  'wher',
#  'ol',
#  'suggested',
#  'poooland',
#  'assumes',
#  'pedofile',
#  'pvt',
#  'pervin',
#  'shivers',
#  'ltnc',
#  'borat',
#  'coffe',
#  'fawked',
#  'meeeeeeeeeeeee',
#  'victims',
#  'crosses',
#  'delivers',
#  'bandsaw',
#  'afk',
#  'tonawanda',
#  'pmers',
#  'sucks',
#  'stationed',
#  'hiiii',
#  'touches',
#  'ck',
#  'kittie',
#  'rubs',
#  'gamefly',
#  'ltns',
#  'dsklgjsdk',
#  'tosses',
#  'ufc',
#  'yoko',
#  'bootay',
#  'hendrix',
#  'blessings',
#  'mmmmmmmmmmmmmm',
#  'injureis',
#  'changed',
#  'ladis',
#  'lousiana',
#  'paypal',
#  'whupped',
#  'signed',
#  'voices',
#  'iamahotnip',
#  'sharing',
#  'asnwer',
#  'omg',
#  'aloha',
#  'mmm',
#  'cya',
#  'werd',
#  'lubbs',
#  'bruises',
#  'cheeeez',
#  'rocks',
#  'maidstone',
#  'arround',
#  'holds',
#  'sexi',
#  'democrats',
#  'toes',
#  'computers',
#  'eeww',
#  'puhleaze',
#  'lamborghini',
#  'stares',
#  'oppsss',
#  'cdt',
#  'dyslexic',
#  'whistlin',
#  'frenchkiss',
#  'sprays',
#  'streched',
#  'brbbb',
#  'privmsg',
#  'elev',
#  'rooms',
#  'meyooky',
#  'coconuts',
#  'scuk',
#  'xxxed',
#  'shups',
#  'whatca',
#  'congrats',
#  'sympathies',
#  'experimenting',
#  'xxxxxx',
#  'nudes',
#  'wth',
#  'pushes',
#  'takes',
#  'years',
#  'roses',
#  'knw',
#  'notes',
#  'weeks',
#  'shakin',
#  'cigars',
#  'eeekk',
#  'heyy',
#  'feelings',
#  'kisses',
#  'chatland',
#  'lonley',
#  'insuklting',
#  'anymore',
#  'arrived',
#  'posts',
#  'meh',
#  'things',
#  'relaxes',
#  'hmmmmmmmmmm',
#  'homeboys',
#  'whewwwwww',
#  'downloaded',
#  'irl',
#  'ridin',
#  'edgewood',
#  'hissy',
#  'froogle',
#  'shoulders',
#  'grrrrrrrr',
#  'dvd',
#  'ihavehotnips',
#  'yeee',
#  'spain',
#  'raaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  'shouldve',
#  'nakey',
#  'nuttin',
#  ...}
